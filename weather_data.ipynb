# %%
import pandas as pd

# %%
data = pd.read_csv('Weather Data.csv')

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

# %%
data['Hour'] = data['Date/Time'].dt.hour
data['Month'] = data['Date/Time'].dt.month

# %%
data
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather  Hour  \
# 0                   4            8.0     101.24                   Fog     0
# ...

# %%
data = data.drop(columns=['Date/Time'])

# %%
data
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa               Weather  Hour  Month
# ...

# %%
data.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.head()
# Out:
#    Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0    -1.8              -3.9         86                4            8.0
# 1    -1.8              -3.7         87                4            8.0
# 2    -1.8              -3.4         89                7            4.0
# 3    -1.5              -3.2         88                6            4.0
# 4    -1.5              -3.3         88                7            4.8
#
#    Press_kPa               Weather  Hour  Month
# 0     101.24                   Fog     0      1
# 1     101.24                   Fog     1      1
# 2     101.26  Freezing Drizzle,Fog     2      1
# 3     101.27  Freezing Drizzle,Fog     3      1
# 4     101.23                   Fog     4      1

# %%
data[(data.Weather=='Thunderstorms,Heavy Rain Showers')]
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 3582    10.9               9.0         88                9            2.4
#
#       Press_kPa                           Weather  Hour  Month
# 3582     100.26  Thunderstorms,Heavy Rain Showers     6      5

# %%
outcome = data.Weather.apply(lambda x:'Cloudy' if 'Cloudy' in x else 'Clear' if 'Clear' in x else 'Fog' if 'Fog' in x else 'Rain' if 'Rain' in x else 'Snow' if 'Snow' in x else 'Others' )

# %%
outcome = outcome.rename("s_weather")

# %%
new_data = pd.concat([data,outcome],axis=1)

# %%
new_data
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa               Weather  Hour  Month s_weather
# ...

# %%
new_data.s_weather.unique()
# Out:
# array(['Fog', 'Cloudy', 'Rain', 'Clear', 'Snow', 'Others'], dtype=object)

# %%
new_data.columns
# Out:
# Index(['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h',
#        'Visibility_km', 'Press_kPa', 'Weather', 'Hour', 'Month', 's_weather'],
#       dtype='object')

# %%
x = new_data.drop(columns=['Weather', 's_weather'])
y = new_data.s_weather

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=123)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=1000, random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\ubaid.qad\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred_train = lr.predict(x_train)

# %%
y_pred_test = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 0.5840330155115981

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 0.5981787137165623

# %%
from sklearn.metrics import confusion_matrix,precision_score, recall_score,f1_score,classification_report

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.60      0.57      0.58      2742
#       Cloudy       0.55      0.63      0.59      3042
#          Fog       0.74      0.82      0.78       339
#       Others       0.00      0.00      0.00        53
#         Rain       0.52      0.26      0.35       452
#         Snow       0.65      0.59      0.62       399
#
#     accuracy                           0.58      7027
#    macro avg       0.51      0.48      0.49      7027
# weighted avg       0.58      0.58      0.58      7027
# C:\Users\ubaid.qad\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.62      0.57      0.59       690
#       Cloudy       0.56      0.66      0.61       755
#          Fog       0.75      0.84      0.79        87
#       Others       0.00      0.00      0.00        16
#         Rain       0.56      0.26      0.35       108
#         Snow       0.64      0.57      0.61       101
#
#     accuracy                           0.60      1757
#    macro avg       0.52      0.48      0.49      1757
# weighted avg       0.59      0.60      0.59      1757
# C:\Users\ubaid.qad\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
x = new_data.drop(columns=['Weather', 's_weather'])
y = new_data.s_weather

# %%
x_train,x_test,y_train,y_test = train_test_split(new_data.drop(columns=['s_weather']), new_data['s_weather'],test_size=0.2, random_state=42)

# %%
numeric_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler",  MinMaxScaler())
])

# %%
categorical_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ohe",     OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

# %%
preprocess = ColumnTransformer(transformers=[
    ("num", numeric_pipe, num_cols),
    ("cat", categorical_pipe, cat_cols),
])

# %%
pipe = Pipeline(steps=[
    ("prep",   preprocess),
    ("select", SelectKBest(score_func=chi2, k=30)),   
    ("model",  DecisionTreeClassifier(
        criterion="gini",
        max_depth=10,            
        min_samples_split=20,
        min_samples_leaf=10,
        random_state=42
    ))
])

# %%
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6647694934547524

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        Clear       0.67      0.68      0.68       665
#       Cloudy       0.65      0.71      0.68       772
#          Fog       0.86      0.84      0.85        85
#       Others       0.05      0.10      0.07        10
#         Rain       0.55      0.22      0.31       109
#         Snow       0.79      0.62      0.70       116
#
#     accuracy                           0.66      1757
#    macro avg       0.59      0.53      0.55      1757
# weighted avg       0.67      0.66      0.66      1757
